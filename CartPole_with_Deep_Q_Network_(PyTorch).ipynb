# %% [markdown]
# <a href="https://colab.research.google.com/github/mani-droid/data-science-projects/blob/master/CartPole_with_Deep_Q_Network_(PyTorch).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Import Libraries**

# %%
import gym
import numpy as np
import random
from collections import deque
import torch
import torch.nn as nn
import torch.optim as optim

# %% [markdown]
# **Neural Network Structure**

# %%
pip install --upgrade gym
# Out:
# Requirement already satisfied: gym in /usr/local/lib/python3.11/dist-packages (0.26.2)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.11/dist-packages (from gym) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gym) (3.1.1)
# Requirement already satisfied: gym_notices>=0.0.4 in /usr/local/lib/python3.11/dist-packages (from gym) (0.0.8)

# %%
# !pip install numpy==1.23.5 --quiet

# %%
class DQN(nn.Module):
  def __init__(self, input_dim, output_dim):
    super(DQN, self).__init__()
    self.fc1 = nn.Linear(input_dim, 128)
    self.fc2 = nn.Linear(128, 64)
    self.fc3 = nn.Linear(64, output_dim)

  def forward(self, x):
    x = torch.relu(self.fc1(x))
    x = torch.relu(self.fc2(x))
    return self.fc3(x)

# %% [markdown]
# **HyperParameters**

# %%
env = gym.make("CartPole-v1", render_mode = None)
input_dim = env.observation_space.shape[0]
output_dim = env.action_space.n

lr = 0.001
gamma = 0.99
epsilon = 1.0
epsilon_decay = 0.995
epsilon_min = 0.01
batch_size = 64
max_episodes = 500
buffer_size = 10000
target_update = 10

# %% [markdown]
# **Replay Buffer**

# %%
replay_buffer = deque(maxlen = buffer_size)

def sample_experiences():
  batch = random.sample(replay_buffer, batch_size)
  states, actions, rewards, next_states, dones = zip(*batch)
  return (np.array(states), actions, rewards, np.array(next_states), dones)

# %% [markdown]
# **Initialize Networks**

# %%
#device = torch.device("cuda" if torch.cuda is available() else "cpu")

policy_net = DQN(input_dim, output_dim)
target_net = DQN(input_dim, output_dim)
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()

optimizer = optim.Adam(policy_net.parameters(), lr = lr)
loss_fn = nn.MSELoss()

# %% [markdown]
# **Training Loop**

# %%
for episode in range(max_episodes):
  state, _ = env.reset()
  total_reward = 0


  for t in range(500):
    state_array = np.array(state)
    state_tensor = torch.tensor(state_array, dtype = torch.float32).unsqueeze(0)


    if random.random() < epsilon:
      action = random.choice(range(output_dim))
    else:
      with torch.no_grad():
        q_values = policy_net(state_tensor)
        action = torch.argmax(q_values).item()


    next_state, reward, terminated, truncated, _ = env.step(action)
    done = terminated or truncated
    total_reward += reward

    replay_buffer.append((state, action, reward, next_state, done))
    state = next_state

    if len(replay_buffer) >= batch_size:
      states, actions, rewards, next_states, dones = sample_experiences()


      states = torch.tensor(states, dtype = torch.float32)
      next_states = torch.tensor(next_states, dtype = torch.float32)
      actions = torch.tensor(actions).unsqueeze(1)
      rewards = torch.tensor(rewards, dtype = torch.float32).unsqueeze(1)
      dones = torch.BoolTensor(dones).unsqueeze(1)

      q_values = policy_net(states).gather(1, actions)
      next_q_values = target_net(next_states).max(1)[0].unsqueeze(1)
      target_q = rewards + gamma * next_q_values * (~dones)

      loss = loss_fn(q_values, target_q.detach())
      optimizer.zero_grad()
      loss.backward()
      optimizer.step()

    if done:
      break

    epsilon = max(epsilon_min, epsilon * epsilon_decay)


    if episode%target_update == 0:
      target_net.load_state_dict(policy_net.state_dict())
  print(f"Episode {episode} | Reward: {total_reward:.2f} | Epsilon: {epsilon:.3f}")
# Out:
# Episode 0 | Reward: 34.00 | Epsilon: 0.848
# Episode 1 | Reward: 15.00 | Epsilon: 0.790
# Episode 2 | Reward: 13.00 | Epsilon: 0.744
# Episode 3 | Reward: 34.00 | Epsilon: 0.631
# Episode 4 | Reward: 10.00 | Epsilon: 0.603
# Episode 5 | Reward: 12.00 | Epsilon: 0.570
# Episode 6 | Reward: 11.00 | Epsilon: 0.543
# Episode 7 | Reward: 22.00 | Epsilon: 0.488
# Episode 8 | Reward: 9.00 | Epsilon: 0.469
# Episode 9 | Reward: 15.00 | Epsilon: 0.437
# Episode 10 | Reward: 10.00 | Epsilon: 0.418
# Episode 11 | Reward: 11.00 | Epsilon: 0.398
# Episode 12 | Reward: 13.00 | Epsilon: 0.374
# Episode 13 | Reward: 10.00 | Epsilon: 0.358
# Episode 14 | Reward: 11.00 | Epsilon: 0.340
# Episode 15 | Reward: 9.00 | Epsilon: 0.327
# Episode 16 | Reward: 12.00 | Epsilon: 0.309
# Episode 17 | Reward: 13.00 | Epsilon: 0.291
# Episode 18 | Reward: 11.00 | Epsilon: 0.277
# Episode 19 | Reward: 12.00 | Epsilon: 0.262
# Episode 20 | Reward: 9.00 | Epsilon: 0.252
# Episode 21 | Reward: 9.00 | Epsilon: 0.242
# Episode 22 | Reward: 13.00 | Epsilon: 0.228
# Episode 23 | Reward: 13.00 | Epsilon: 0.215
# Episode 24 | Reward: 13.00 | Epsilon: 0.202
# Episode 25 | Reward: 16.00 | Epsilon: 0.187
# Episode 26 | Reward: 12.00 | Epsilon: 0.177
# Episode 27 | Reward: 10.00 | Epsilon: 0.170
# Episode 28 | Reward: 14.00 | Epsilon: 0.159
# Episode 29 | Reward: 9.00 | Epsilon: 0.153
# Episode 30 | Reward: 10.00 | Epsilon: 0.146
# Episode 31 | Reward: 9.00 | Epsilon: 0.140
# Episode 32 | Reward: 11.00 | Epsilon: 0.133
# Episode 33 | Reward: 14.00 | Epsilon: 0.125
# Episode 34 | Reward: 11.00 | Epsilon: 0.119
# Episode 35 | Reward: 9.00 | Epsilon: 0.114
# Episode 36 | Reward: 8.00 | Epsilon: 0.110
# Episode 37 | Reward: 13.00 | Epsilon: 0.104
# Episode 38 | Reward: 11.00 | Epsilon: 0.099
# Episode 39 | Reward: 18.00 | Epsilon: 0.091
# Episode 40 | Reward: 10.00 | Epsilon: 0.087
# Episode 41 | Reward: 18.00 | Epsilon: 0.080
# Episode 42 | Reward: 20.00 | Epsilon: 0.072
# Episode 43 | Reward: 15.00 | Epsilon: 0.067
# Episode 44 | Reward: 22.00 | Epsilon: 0.061
# Episode 45 | Reward: 24.00 | Epsilon: 0.054
# Episode 46 | Reward: 17.00 | Epsilon: 0.050
# Episode 47 | Reward: 27.00 | Epsilon: 0.044
# Episode 48 | Reward: 18.00 | Epsilon: 0.040
# Episode 49 | Reward: 21.00 | Epsilon: 0.036
# Episode 50 | Reward: 17.00 | Epsilon: 0.034
# Episode 51 | Reward: 26.00 | Epsilon: 0.030
# Episode 52 | Reward: 31.00 | Epsilon: 0.025
# Episode 53 | Reward: 39.00 | Epsilon: 0.021
# Episode 54 | Reward: 28.00 | Epsilon: 0.018
# Episode 55 | Reward: 24.00 | Epsilon: 0.016
# Episode 56 | Reward: 29.00 | Epsilon: 0.014
# Episode 57 | Reward: 28.00 | Epsilon: 0.012
# Episode 58 | Reward: 34.00 | Epsilon: 0.011
# Episode 59 | Reward: 23.00 | Epsilon: 0.010
# Episode 60 | Reward: 51.00 | Epsilon: 0.010
# Episode 61 | Reward: 10.00 | Epsilon: 0.010
# Episode 62 | Reward: 20.00 | Epsilon: 0.010
# Episode 63 | Reward: 30.00 | Epsilon: 0.010
# Episode 64 | Reward: 108.00 | Epsilon: 0.010
# Episode 65 | Reward: 86.00 | Epsilon: 0.010
# Episode 66 | Reward: 85.00 | Epsilon: 0.010
# Episode 67 | Reward: 159.00 | Epsilon: 0.010
# Episode 68 | Reward: 143.00 | Epsilon: 0.010
# Episode 69 | Reward: 112.00 | Epsilon: 0.010
# Episode 70 | Reward: 90.00 | Epsilon: 0.010
# Episode 71 | Reward: 89.00 | Epsilon: 0.010
# Episode 72 | Reward: 89.00 | Epsilon: 0.010
# Episode 73 | Reward: 67.00 | Epsilon: 0.010
# Episode 74 | Reward: 96.00 | Epsilon: 0.010
# Episode 75 | Reward: 136.00 | Epsilon: 0.010
# Episode 76 | Reward: 112.00 | Epsilon: 0.010
# Episode 77 | Reward: 96.00 | Epsilon: 0.010
# Episode 78 | Reward: 98.00 | Epsilon: 0.010
# Episode 79 | Reward: 96.00 | Epsilon: 0.010
# Episode 80 | Reward: 109.00 | Epsilon: 0.010
# Episode 81 | Reward: 46.00 | Epsilon: 0.010
# Episode 82 | Reward: 41.00 | Epsilon: 0.010
# Episode 83 | Reward: 69.00 | Epsilon: 0.010
# Episode 84 | Reward: 55.00 | Epsilon: 0.010
# Episode 85 | Reward: 56.00 | Epsilon: 0.010
# Episode 86 | Reward: 72.00 | Epsilon: 0.010
# Episode 87 | Reward: 63.00 | Epsilon: 0.010
# Episode 88 | Reward: 96.00 | Epsilon: 0.010
# Episode 89 | Reward: 64.00 | Epsilon: 0.010
# Episode 90 | Reward: 62.00 | Epsilon: 0.010
# Episode 91 | Reward: 212.00 | Epsilon: 0.010
# Episode 92 | Reward: 193.00 | Epsilon: 0.010
# Episode 93 | Reward: 190.00 | Epsilon: 0.010
# Episode 94 | Reward: 214.00 | Epsilon: 0.010
# Episode 95 | Reward: 230.00 | Epsilon: 0.010
# Episode 96 | Reward: 249.00 | Epsilon: 0.010
# Episode 97 | Reward: 194.00 | Epsilon: 0.010
# Episode 98 | Reward: 185.00 | Epsilon: 0.010
# Episode 99 | Reward: 209.00 | Epsilon: 0.010
# Episode 100 | Reward: 287.00 | Epsilon: 0.010
# Episode 101 | Reward: 103.00 | Epsilon: 0.010
# Episode 102 | Reward: 206.00 | Epsilon: 0.010
# Episode 103 | Reward: 158.00 | Epsilon: 0.010
# Episode 104 | Reward: 166.00 | Epsilon: 0.010
# Episode 105 | Reward: 354.00 | Epsilon: 0.010
# Episode 106 | Reward: 372.00 | Epsilon: 0.010
# Episode 107 | Reward: 434.00 | Epsilon: 0.010
# Episode 108 | Reward: 500.00 | Epsilon: 0.010
# Episode 109 | Reward: 329.00 | Epsilon: 0.010
# Episode 110 | Reward: 232.00 | Epsilon: 0.010
# Episode 111 | Reward: 246.00 | Epsilon: 0.010
# Episode 112 | Reward: 216.00 | Epsilon: 0.010
# Episode 113 | Reward: 223.00 | Epsilon: 0.010
# Episode 114 | Reward: 262.00 | Epsilon: 0.010
# Episode 115 | Reward: 219.00 | Epsilon: 0.010
# Episode 116 | Reward: 219.00 | Epsilon: 0.010
# Episode 117 | Reward: 255.00 | Epsilon: 0.010
# Episode 118 | Reward: 321.00 | Epsilon: 0.010
# Episode 119 | Reward: 254.00 | Epsilon: 0.010
# Episode 120 | Reward: 299.00 | Epsilon: 0.010
# Episode 121 | Reward: 232.00 | Epsilon: 0.010
# Episode 122 | Reward: 261.00 | Epsilon: 0.010
# Episode 123 | Reward: 293.00 | Epsilon: 0.010
# Episode 124 | Reward: 222.00 | Epsilon: 0.010
# Episode 125 | Reward: 214.00 | Epsilon: 0.010
# Episode 126 | Reward: 222.00 | Epsilon: 0.010
# Episode 127 | Reward: 272.00 | Epsilon: 0.010
# Episode 128 | Reward: 204.00 | Epsilon: 0.010
# Episode 129 | Reward: 288.00 | Epsilon: 0.010
# Episode 130 | Reward: 201.00 | Epsilon: 0.010
# Episode 131 | Reward: 208.00 | Epsilon: 0.010
# Episode 132 | Reward: 382.00 | Epsilon: 0.010
# Episode 133 | Reward: 500.00 | Epsilon: 0.010
# Episode 134 | Reward: 316.00 | Epsilon: 0.010
# Episode 135 | Reward: 359.00 | Epsilon: 0.010
# Episode 136 | Reward: 394.00 | Epsilon: 0.010
# Episode 137 | Reward: 286.00 | Epsilon: 0.010
# Episode 138 | Reward: 241.00 | Epsilon: 0.010
# Episode 139 | Reward: 269.00 | Epsilon: 0.010
# Episode 140 | Reward: 216.00 | Epsilon: 0.010
# Episode 141 | Reward: 228.00 | Epsilon: 0.010
# Episode 142 | Reward: 247.00 | Epsilon: 0.010
# Episode 143 | Reward: 301.00 | Epsilon: 0.010
# Episode 144 | Reward: 316.00 | Epsilon: 0.010
# Episode 145 | Reward: 361.00 | Epsilon: 0.010
# Episode 146 | Reward: 202.00 | Epsilon: 0.010
# Episode 147 | Reward: 399.00 | Epsilon: 0.010
# Episode 148 | Reward: 220.00 | Epsilon: 0.010
# Episode 149 | Reward: 260.00 | Epsilon: 0.010
# Episode 150 | Reward: 201.00 | Epsilon: 0.010
# Episode 151 | Reward: 242.00 | Epsilon: 0.010
# Episode 152 | Reward: 200.00 | Epsilon: 0.010
# Episode 153 | Reward: 283.00 | Epsilon: 0.010
# Episode 154 | Reward: 209.00 | Epsilon: 0.010
# Episode 155 | Reward: 380.00 | Epsilon: 0.010
# Episode 156 | Reward: 241.00 | Epsilon: 0.010
# Episode 157 | Reward: 231.00 | Epsilon: 0.010
# Episode 158 | Reward: 211.00 | Epsilon: 0.010
# Episode 159 | Reward: 283.00 | Epsilon: 0.010
# Episode 160 | Reward: 227.00 | Epsilon: 0.010
# Episode 161 | Reward: 290.00 | Epsilon: 0.010
# Episode 162 | Reward: 250.00 | Epsilon: 0.010
# Episode 163 | Reward: 202.00 | Epsilon: 0.010
# Episode 164 | Reward: 304.00 | Epsilon: 0.010
# Episode 165 | Reward: 201.00 | Epsilon: 0.010
# Episode 166 | Reward: 216.00 | Epsilon: 0.010
# Episode 167 | Reward: 246.00 | Epsilon: 0.010
# Episode 168 | Reward: 304.00 | Epsilon: 0.010
# Episode 169 | Reward: 275.00 | Epsilon: 0.010
# Episode 170 | Reward: 211.00 | Epsilon: 0.010
# Episode 171 | Reward: 217.00 | Epsilon: 0.010
# Episode 172 | Reward: 251.00 | Epsilon: 0.010
# Episode 173 | Reward: 220.00 | Epsilon: 0.010
# Episode 174 | Reward: 229.00 | Epsilon: 0.010
# Episode 175 | Reward: 219.00 | Epsilon: 0.010
# Episode 176 | Reward: 222.00 | Epsilon: 0.010
# Episode 177 | Reward: 209.00 | Epsilon: 0.010
# Episode 178 | Reward: 229.00 | Epsilon: 0.010
# Episode 179 | Reward: 288.00 | Epsilon: 0.010
# Episode 180 | Reward: 199.00 | Epsilon: 0.010
# Episode 181 | Reward: 212.00 | Epsilon: 0.010
# Episode 182 | Reward: 278.00 | Epsilon: 0.010
# Episode 183 | Reward: 244.00 | Epsilon: 0.010
# Episode 184 | Reward: 218.00 | Epsilon: 0.010
# Episode 185 | Reward: 355.00 | Epsilon: 0.010
# Episode 186 | Reward: 266.00 | Epsilon: 0.010
# Episode 187 | Reward: 231.00 | Epsilon: 0.010
# Episode 188 | Reward: 212.00 | Epsilon: 0.010
# Episode 189 | Reward: 208.00 | Epsilon: 0.010
# Episode 190 | Reward: 244.00 | Epsilon: 0.010
# Episode 191 | Reward: 234.00 | Epsilon: 0.010
# Episode 192 | Reward: 296.00 | Epsilon: 0.010
# Episode 193 | Reward: 235.00 | Epsilon: 0.010
# Episode 194 | Reward: 210.00 | Epsilon: 0.010
# Episode 195 | Reward: 208.00 | Epsilon: 0.010
# Episode 196 | Reward: 204.00 | Epsilon: 0.010
# Episode 197 | Reward: 206.00 | Epsilon: 0.010
# Episode 198 | Reward: 240.00 | Epsilon: 0.010
# Episode 199 | Reward: 231.00 | Epsilon: 0.010
# Episode 200 | Reward: 255.00 | Epsilon: 0.010
# Episode 201 | Reward: 290.00 | Epsilon: 0.010
# Episode 202 | Reward: 281.00 | Epsilon: 0.010
# Episode 203 | Reward: 266.00 | Epsilon: 0.010
# Episode 204 | Reward: 218.00 | Epsilon: 0.010
# Episode 205 | Reward: 214.00 | Epsilon: 0.010
# Episode 206 | Reward: 235.00 | Epsilon: 0.010
# Episode 207 | Reward: 217.00 | Epsilon: 0.010
# Episode 208 | Reward: 232.00 | Epsilon: 0.010
# Episode 209 | Reward: 292.00 | Epsilon: 0.010
# Episode 210 | Reward: 257.00 | Epsilon: 0.010
# Episode 211 | Reward: 208.00 | Epsilon: 0.010
# Episode 212 | Reward: 256.00 | Epsilon: 0.010
# Episode 213 | Reward: 293.00 | Epsilon: 0.010
# Episode 214 | Reward: 189.00 | Epsilon: 0.010
# Episode 215 | Reward: 237.00 | Epsilon: 0.010
# Episode 216 | Reward: 246.00 | Epsilon: 0.010
# Episode 217 | Reward: 351.00 | Epsilon: 0.010
# Episode 218 | Reward: 306.00 | Epsilon: 0.010
# Episode 219 | Reward: 225.00 | Epsilon: 0.010
# Episode 220 | Reward: 204.00 | Epsilon: 0.010
# Episode 221 | Reward: 277.00 | Epsilon: 0.010
# Episode 222 | Reward: 247.00 | Epsilon: 0.010
# Episode 223 | Reward: 256.00 | Epsilon: 0.010
# Episode 224 | Reward: 316.00 | Epsilon: 0.010
# Episode 225 | Reward: 248.00 | Epsilon: 0.010
# Episode 226 | Reward: 271.00 | Epsilon: 0.010
# Episode 227 | Reward: 212.00 | Epsilon: 0.010
# Episode 228 | Reward: 246.00 | Epsilon: 0.010
# Episode 229 | Reward: 246.00 | Epsilon: 0.010
# Episode 230 | Reward: 150.00 | Epsilon: 0.010
# Episode 231 | Reward: 10.00 | Epsilon: 0.010
# Episode 232 | Reward: 11.00 | Epsilon: 0.010
# Episode 233 | Reward: 11.00 | Epsilon: 0.010
# Episode 234 | Reward: 12.00 | Epsilon: 0.010
# Episode 235 | Reward: 10.00 | Epsilon: 0.010
# Episode 236 | Reward: 11.00 | Epsilon: 0.010
# Episode 237 | Reward: 9.00 | Epsilon: 0.010
# Episode 238 | Reward: 12.00 | Epsilon: 0.010
# Episode 239 | Reward: 14.00 | Epsilon: 0.010
# Episode 240 | Reward: 12.00 | Epsilon: 0.010
# Episode 241 | Reward: 12.00 | Epsilon: 0.010
# Episode 242 | Reward: 11.00 | Epsilon: 0.010
# Episode 243 | Reward: 12.00 | Epsilon: 0.010
# Episode 244 | Reward: 10.00 | Epsilon: 0.010
# Episode 245 | Reward: 10.00 | Epsilon: 0.010
# Episode 246 | Reward: 12.00 | Epsilon: 0.010
# Episode 247 | Reward: 11.00 | Epsilon: 0.010
# Episode 248 | Reward: 11.00 | Epsilon: 0.010
# Episode 249 | Reward: 10.00 | Epsilon: 0.010
# Episode 250 | Reward: 11.00 | Epsilon: 0.010
# Episode 251 | Reward: 12.00 | Epsilon: 0.010
# Episode 252 | Reward: 18.00 | Epsilon: 0.010
# Episode 253 | Reward: 12.00 | Epsilon: 0.010
# Episode 254 | Reward: 13.00 | Epsilon: 0.010
# Episode 255 | Reward: 18.00 | Epsilon: 0.010
# Episode 256 | Reward: 20.00 | Epsilon: 0.010
# Episode 257 | Reward: 23.00 | Epsilon: 0.010
# Episode 258 | Reward: 18.00 | Epsilon: 0.010
# Episode 259 | Reward: 22.00 | Epsilon: 0.010
# Episode 260 | Reward: 129.00 | Epsilon: 0.010
# Episode 261 | Reward: 143.00 | Epsilon: 0.010
# Episode 262 | Reward: 154.00 | Epsilon: 0.010
# Episode 263 | Reward: 167.00 | Epsilon: 0.010
# Episode 264 | Reward: 150.00 | Epsilon: 0.010
# Episode 265 | Reward: 164.00 | Epsilon: 0.010
# Episode 266 | Reward: 196.00 | Epsilon: 0.010
# Episode 267 | Reward: 193.00 | Epsilon: 0.010
# Episode 268 | Reward: 188.00 | Epsilon: 0.010
# Episode 269 | Reward: 191.00 | Epsilon: 0.010
# Episode 270 | Reward: 445.00 | Epsilon: 0.010
# Episode 271 | Reward: 168.00 | Epsilon: 0.010
# Episode 272 | Reward: 171.00 | Epsilon: 0.010
# Episode 273 | Reward: 325.00 | Epsilon: 0.010
# Episode 274 | Reward: 224.00 | Epsilon: 0.010
# Episode 275 | Reward: 296.00 | Epsilon: 0.010
# Episode 276 | Reward: 247.00 | Epsilon: 0.010
# Episode 277 | Reward: 343.00 | Epsilon: 0.010
# Episode 278 | Reward: 291.00 | Epsilon: 0.010
# Episode 279 | Reward: 366.00 | Epsilon: 0.010
# Episode 280 | Reward: 240.00 | Epsilon: 0.010
# Episode 281 | Reward: 176.00 | Epsilon: 0.010
# Episode 282 | Reward: 333.00 | Epsilon: 0.010
# Episode 283 | Reward: 344.00 | Epsilon: 0.010
# Episode 284 | Reward: 246.00 | Epsilon: 0.010
# Episode 285 | Reward: 188.00 | Epsilon: 0.010
# Episode 286 | Reward: 181.00 | Epsilon: 0.010
# Episode 287 | Reward: 199.00 | Epsilon: 0.010
# Episode 288 | Reward: 459.00 | Epsilon: 0.010
# Episode 289 | Reward: 229.00 | Epsilon: 0.010
# Episode 290 | Reward: 273.00 | Epsilon: 0.010
# Episode 291 | Reward: 220.00 | Epsilon: 0.010
# Episode 292 | Reward: 341.00 | Epsilon: 0.010
# Episode 293 | Reward: 291.00 | Epsilon: 0.010
# Episode 294 | Reward: 268.00 | Epsilon: 0.010
# Episode 295 | Reward: 231.00 | Epsilon: 0.010
# Episode 296 | Reward: 225.00 | Epsilon: 0.010
# Episode 297 | Reward: 500.00 | Epsilon: 0.010
# Episode 298 | Reward: 306.00 | Epsilon: 0.010
# Episode 299 | Reward: 316.00 | Epsilon: 0.010
# Episode 300 | Reward: 296.00 | Epsilon: 0.010
# Episode 301 | Reward: 254.00 | Epsilon: 0.010
# Episode 302 | Reward: 255.00 | Epsilon: 0.010
# Episode 303 | Reward: 254.00 | Epsilon: 0.010
# Episode 304 | Reward: 253.00 | Epsilon: 0.010
# Episode 305 | Reward: 290.00 | Epsilon: 0.010
# Episode 306 | Reward: 262.00 | Epsilon: 0.010
# Episode 307 | Reward: 500.00 | Epsilon: 0.010
# Episode 308 | Reward: 247.00 | Epsilon: 0.010
# Episode 309 | Reward: 252.00 | Epsilon: 0.010
# Episode 310 | Reward: 222.00 | Epsilon: 0.010
# Episode 311 | Reward: 9.00 | Epsilon: 0.010
# Episode 312 | Reward: 9.00 | Epsilon: 0.010
# Episode 313 | Reward: 10.00 | Epsilon: 0.010
# Episode 314 | Reward: 9.00 | Epsilon: 0.010
# Episode 315 | Reward: 8.00 | Epsilon: 0.010
# Episode 316 | Reward: 10.00 | Epsilon: 0.010
# Episode 317 | Reward: 8.00 | Epsilon: 0.010
# Episode 318 | Reward: 8.00 | Epsilon: 0.010
# Episode 319 | Reward: 10.00 | Epsilon: 0.010
# Episode 320 | Reward: 8.00 | Epsilon: 0.010
# Episode 321 | Reward: 8.00 | Epsilon: 0.010
# Episode 322 | Reward: 10.00 | Epsilon: 0.010
# Episode 323 | Reward: 10.00 | Epsilon: 0.010
# Episode 324 | Reward: 11.00 | Epsilon: 0.010
# Episode 325 | Reward: 9.00 | Epsilon: 0.010
# Episode 326 | Reward: 10.00 | Epsilon: 0.010
# Episode 327 | Reward: 10.00 | Epsilon: 0.010
# Episode 328 | Reward: 9.00 | Epsilon: 0.010
# Episode 329 | Reward: 9.00 | Epsilon: 0.010
# Episode 330 | Reward: 8.00 | Epsilon: 0.010
# Episode 331 | Reward: 10.00 | Epsilon: 0.010
# Episode 332 | Reward: 10.00 | Epsilon: 0.010
# Episode 333 | Reward: 9.00 | Epsilon: 0.010
# Episode 334 | Reward: 9.00 | Epsilon: 0.010
# Episode 335 | Reward: 10.00 | Epsilon: 0.010
# Episode 336 | Reward: 9.00 | Epsilon: 0.010
# Episode 337 | Reward: 9.00 | Epsilon: 0.010
# Episode 338 | Reward: 10.00 | Epsilon: 0.010
# Episode 339 | Reward: 8.00 | Epsilon: 0.010
# Episode 340 | Reward: 10.00 | Epsilon: 0.010
# Episode 341 | Reward: 10.00 | Epsilon: 0.010
# Episode 342 | Reward: 10.00 | Epsilon: 0.010
# Episode 343 | Reward: 10.00 | Epsilon: 0.010
# Episode 344 | Reward: 8.00 | Epsilon: 0.010
# Episode 345 | Reward: 9.00 | Epsilon: 0.010
# Episode 346 | Reward: 10.00 | Epsilon: 0.010
# Episode 347 | Reward: 8.00 | Epsilon: 0.010
# Episode 348 | Reward: 10.00 | Epsilon: 0.010
# Episode 349 | Reward: 9.00 | Epsilon: 0.010
# Episode 350 | Reward: 9.00 | Epsilon: 0.010
# Episode 351 | Reward: 10.00 | Epsilon: 0.010
# Episode 352 | Reward: 9.00 | Epsilon: 0.010
# Episode 353 | Reward: 12.00 | Epsilon: 0.010
# Episode 354 | Reward: 10.00 | Epsilon: 0.010
# Episode 355 | Reward: 14.00 | Epsilon: 0.010
# Episode 356 | Reward: 13.00 | Epsilon: 0.010
# Episode 357 | Reward: 14.00 | Epsilon: 0.010
# Episode 358 | Reward: 15.00 | Epsilon: 0.010
# Episode 359 | Reward: 12.00 | Epsilon: 0.010
# Episode 360 | Reward: 17.00 | Epsilon: 0.010
# Episode 361 | Reward: 21.00 | Epsilon: 0.010
# Episode 362 | Reward: 66.00 | Epsilon: 0.010
# Episode 363 | Reward: 71.00 | Epsilon: 0.010
# Episode 364 | Reward: 66.00 | Epsilon: 0.010
# Episode 365 | Reward: 64.00 | Epsilon: 0.010
# Episode 366 | Reward: 73.00 | Epsilon: 0.010
# Episode 367 | Reward: 78.00 | Epsilon: 0.010
# Episode 368 | Reward: 74.00 | Epsilon: 0.010
# Episode 369 | Reward: 66.00 | Epsilon: 0.010
# Episode 370 | Reward: 76.00 | Epsilon: 0.010
# Episode 371 | Reward: 147.00 | Epsilon: 0.010
# Episode 372 | Reward: 410.00 | Epsilon: 0.010
# Episode 373 | Reward: 328.00 | Epsilon: 0.010
# Episode 374 | Reward: 441.00 | Epsilon: 0.010
# Episode 375 | Reward: 187.00 | Epsilon: 0.010
# Episode 376 | Reward: 319.00 | Epsilon: 0.010
# Episode 377 | Reward: 405.00 | Epsilon: 0.010
# Episode 378 | Reward: 500.00 | Epsilon: 0.010
# Episode 379 | Reward: 500.00 | Epsilon: 0.010
# Episode 380 | Reward: 500.00 | Epsilon: 0.010
# Episode 381 | Reward: 500.00 | Epsilon: 0.010
# Episode 382 | Reward: 500.00 | Epsilon: 0.010
# Episode 383 | Reward: 268.00 | Epsilon: 0.010
# Episode 384 | Reward: 198.00 | Epsilon: 0.010
# Episode 385 | Reward: 233.00 | Epsilon: 0.010
# Episode 386 | Reward: 282.00 | Epsilon: 0.010
# Episode 387 | Reward: 199.00 | Epsilon: 0.010
# Episode 388 | Reward: 237.00 | Epsilon: 0.010
# Episode 389 | Reward: 192.00 | Epsilon: 0.010
# Episode 390 | Reward: 182.00 | Epsilon: 0.010
# Episode 391 | Reward: 153.00 | Epsilon: 0.010
# Episode 392 | Reward: 170.00 | Epsilon: 0.010
# Episode 393 | Reward: 177.00 | Epsilon: 0.010
# Episode 394 | Reward: 172.00 | Epsilon: 0.010
# Episode 395 | Reward: 182.00 | Epsilon: 0.010
# Episode 396 | Reward: 169.00 | Epsilon: 0.010
# Episode 397 | Reward: 198.00 | Epsilon: 0.010
# Episode 398 | Reward: 175.00 | Epsilon: 0.010
# Episode 399 | Reward: 199.00 | Epsilon: 0.010
# Episode 400 | Reward: 184.00 | Epsilon: 0.010
# Episode 401 | Reward: 211.00 | Epsilon: 0.010
# Episode 402 | Reward: 226.00 | Epsilon: 0.010
# Episode 403 | Reward: 277.00 | Epsilon: 0.010
# Episode 404 | Reward: 250.00 | Epsilon: 0.010
# Episode 405 | Reward: 235.00 | Epsilon: 0.010
# Episode 406 | Reward: 285.00 | Epsilon: 0.010
# Episode 407 | Reward: 313.00 | Epsilon: 0.010
# Episode 408 | Reward: 348.00 | Epsilon: 0.010
# Episode 409 | Reward: 281.00 | Epsilon: 0.010
# Episode 410 | Reward: 212.00 | Epsilon: 0.010
# Episode 411 | Reward: 207.00 | Epsilon: 0.010
# Episode 412 | Reward: 247.00 | Epsilon: 0.010
# Episode 413 | Reward: 232.00 | Epsilon: 0.010
# Episode 414 | Reward: 265.00 | Epsilon: 0.010
# Episode 415 | Reward: 241.00 | Epsilon: 0.010
# Episode 416 | Reward: 260.00 | Epsilon: 0.010
# Episode 417 | Reward: 237.00 | Epsilon: 0.010
# Episode 418 | Reward: 253.00 | Epsilon: 0.010
# Episode 419 | Reward: 239.00 | Epsilon: 0.010
# Episode 420 | Reward: 181.00 | Epsilon: 0.010
# Episode 421 | Reward: 183.00 | Epsilon: 0.010
# Episode 422 | Reward: 187.00 | Epsilon: 0.010
# Episode 423 | Reward: 252.00 | Epsilon: 0.010
# Episode 424 | Reward: 219.00 | Epsilon: 0.010
# Episode 425 | Reward: 201.00 | Epsilon: 0.010
# Episode 426 | Reward: 186.00 | Epsilon: 0.010
# Episode 427 | Reward: 200.00 | Epsilon: 0.010
# Episode 428 | Reward: 212.00 | Epsilon: 0.010
# Episode 429 | Reward: 185.00 | Epsilon: 0.010
# Episode 430 | Reward: 156.00 | Epsilon: 0.010
# Episode 431 | Reward: 163.00 | Epsilon: 0.010
# Episode 432 | Reward: 175.00 | Epsilon: 0.010
# Episode 433 | Reward: 307.00 | Epsilon: 0.010
# Episode 434 | Reward: 353.00 | Epsilon: 0.010
# Episode 435 | Reward: 500.00 | Epsilon: 0.010
# Episode 436 | Reward: 500.00 | Epsilon: 0.010
# Episode 437 | Reward: 485.00 | Epsilon: 0.010
# Episode 438 | Reward: 500.00 | Epsilon: 0.010
# Episode 439 | Reward: 408.00 | Epsilon: 0.010
# Episode 440 | Reward: 500.00 | Epsilon: 0.010
# Episode 441 | Reward: 500.00 | Epsilon: 0.010
# Episode 442 | Reward: 393.00 | Epsilon: 0.010
# Episode 443 | Reward: 250.00 | Epsilon: 0.010
# Episode 444 | Reward: 410.00 | Epsilon: 0.010
# Episode 445 | Reward: 307.00 | Epsilon: 0.010
# Episode 446 | Reward: 403.00 | Epsilon: 0.010
# Episode 447 | Reward: 325.00 | Epsilon: 0.010
# Episode 448 | Reward: 331.00 | Epsilon: 0.010
# Episode 449 | Reward: 366.00 | Epsilon: 0.010
# Episode 450 | Reward: 143.00 | Epsilon: 0.010
# Episode 451 | Reward: 9.00 | Epsilon: 0.010
# Episode 452 | Reward: 9.00 | Epsilon: 0.010
# Episode 453 | Reward: 10.00 | Epsilon: 0.010
# Episode 454 | Reward: 10.00 | Epsilon: 0.010
# Episode 455 | Reward: 11.00 | Epsilon: 0.010
# Episode 456 | Reward: 14.00 | Epsilon: 0.010
# Episode 457 | Reward: 11.00 | Epsilon: 0.010
# Episode 458 | Reward: 9.00 | Epsilon: 0.010
# Episode 459 | Reward: 10.00 | Epsilon: 0.010
# Episode 460 | Reward: 99.00 | Epsilon: 0.010
# Episode 461 | Reward: 275.00 | Epsilon: 0.010
# Episode 462 | Reward: 177.00 | Epsilon: 0.010
# Episode 463 | Reward: 213.00 | Epsilon: 0.010
# Episode 464 | Reward: 177.00 | Epsilon: 0.010
# Episode 465 | Reward: 161.00 | Epsilon: 0.010
# Episode 466 | Reward: 449.00 | Epsilon: 0.010
# Episode 467 | Reward: 367.00 | Epsilon: 0.010
# Episode 468 | Reward: 227.00 | Epsilon: 0.010
# Episode 469 | Reward: 331.00 | Epsilon: 0.010
# Episode 470 | Reward: 271.00 | Epsilon: 0.010
# Episode 471 | Reward: 160.00 | Epsilon: 0.010
# Episode 472 | Reward: 240.00 | Epsilon: 0.010
# Episode 473 | Reward: 240.00 | Epsilon: 0.010
# Episode 474 | Reward: 392.00 | Epsilon: 0.010
# Episode 475 | Reward: 424.00 | Epsilon: 0.010
# Episode 476 | Reward: 292.00 | Epsilon: 0.010
# Episode 477 | Reward: 219.00 | Epsilon: 0.010
# Episode 478 | Reward: 500.00 | Epsilon: 0.010
# Episode 479 | Reward: 500.00 | Epsilon: 0.010
# Episode 480 | Reward: 371.00 | Epsilon: 0.010
# Episode 481 | Reward: 360.00 | Epsilon: 0.010
# Episode 482 | Reward: 500.00 | Epsilon: 0.010
# Episode 483 | Reward: 500.00 | Epsilon: 0.010
# Episode 484 | Reward: 500.00 | Epsilon: 0.010
# Episode 485 | Reward: 375.00 | Epsilon: 0.010
# Episode 486 | Reward: 423.00 | Epsilon: 0.010
# Episode 487 | Reward: 500.00 | Epsilon: 0.010
# Episode 488 | Reward: 445.00 | Epsilon: 0.010
# Episode 489 | Reward: 429.00 | Epsilon: 0.010
# Episode 490 | Reward: 500.00 | Epsilon: 0.010
# Episode 491 | Reward: 500.00 | Epsilon: 0.010
# Episode 492 | Reward: 355.00 | Epsilon: 0.010
# Episode 493 | Reward: 304.00 | Epsilon: 0.010
# Episode 494 | Reward: 500.00 | Epsilon: 0.010
# Episode 495 | Reward: 500.00 | Epsilon: 0.010
# Episode 496 | Reward: 500.00 | Epsilon: 0.010
# Episode 497 | Reward: 500.00 | Epsilon: 0.010
# Episode 498 | Reward: 69.00 | Epsilon: 0.010
# Episode 499 | Reward: 75.00 | Epsilon: 0.010
